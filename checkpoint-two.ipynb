# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# https://www.kaggle.com/vesuvius13/serial-killers-dataset
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
# import pandas
import pandas as pd


# create your data frames using .read_csv 
highest_vc = pd.read_csv('Highest_victim_count.csv')

vc_15_to_30 = pd.read_csv('15_to_30_victim_count.csv')

vc_5_to_14 = pd.read_csv('5_to_14_victim_count.csv')

vc_lessthan_5 = pd.read_csv('Lessthan_5_victim_count.csv')

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
#seeing top 5 rows to get an idea of what df looks like
highest_vc.head()
# Out:
#                      Name                                  Country  \
# 0  Luis Garavito           Colombia\r\nEcuador\r\nVenezuela
# 1  Pedro López             Colombia\r\nPeru\r\nEcuador
# 2  Javed Iqbal             Pakistan
# 3  Mikhail Popkov          Russia
# 4  Daniel Camargo Barbosa  Colombia\r\nEcuador\r\nBrazil (alleged)
#
#    Years active  Proven victims Possible victims  \
# 0  1992 to 1999  138             172–300+
# 1  1969 to 1979  110             300+
# 2  1998 to 1999  100             100
# 3  1992 to 2010  83              83+
# 4  1974 to 1986  72              180
#
# ...

# %%
#seeing bottom 5 rows to get an idea of what df looks like
highest_vc.tail()
# Out:
#                            Name                           Country  \
# 29  Ali Asghar Borujerdi         Ottoman Empire\r\n Iraq\r\n Iran
# 30  Vasili Komaroff              Soviet Union
# 31  Fernando Hernández Leyva     Mexico
# 32  Ramadan Abdel Rehim Mansour  Egypt
# 33  Radik Tagirov                Russia
#
#     Years active  Proven victims Possible victims  \
# 29  1907 to 1934  33              33
# 30  1921 to 1923  33              33
# 31  1982 to 1999  33              100+
# 32  1999 to 2006  32              32+
# 33  2011 to 2012  32              32
#
# ...

# %%
#finding avg, min, and max
highest_vc.describe()
# Out:
#        Proven victims
# count  34.000000
# mean   52.764706
# std    24.601132
# min    32.000000
# 25%    35.250000
# 50%    46.500000
# 75%    59.500000
# max    138.000000

# %%
#seeing top 5 rows to get an idea of what df looks like
vc_15_to_30.head()
# Out:
#                                       Name    Country  Years active  \
# 0  Karl Denke                               Germany    1900 to 1924
# 1  Francisco das Chagas Rodrigues de Brito  Brazil     1989 to 2003
# 2  Luis Gregorio Ramírez Maestre            Colombia   2010 to 2013
# 3  David Thabo Simelane                     Swaziland  2000 to 2001
# 4  Zhang Jun                                China      1993 to 2000
#
#    Proven victims Possible victims  \
# 0  30              42+
# 1  30              42
# 2  30              30
# 3  28              45
# 4  28              28
#
# ...

# %%
#seeing bottom 5 rows to get an idea of what df looks like
vc_15_to_30.tail()
# Out:
#                    Name       Country   Years active  Proven victims  \
# 73  Elifasi Msomi        South Africa  1950s to 1956  15
# 74  Florencio Fernández  Argentina     1950s          15
# 75  Bai Baoshan          China         1983 to 1997   15
# 76  Maurizio Minghella   Italy         1978 to 2001   15
# 77  Alexander Labutkin   Soviet Union  1933 to 1935   15
#
#    Possible victims  \
# 73  15
# 74  15
# 75  15
# 76  15
# 77  15
#
#                                                                                                                                      Notes
# 73  Killed his victims with an axe or a knife in the 1950s; executed by hanging in 1956.
# 74  Stalked his victims, then would beat and bite them while they were asleep. Died from natural causes a few years after his 1960 arrest.
# 75  Robber who killed 15 people while robbing several police stations; executed by gunshot in 1998.
# ...

# %%
#finding avg, min, and max
vc_15_to_30.describe()
# Out:
#        Proven victims
# count  78.000000
# mean   19.294872
# std    4.099759
# min    15.000000
# 25%    16.000000
# 50%    18.000000
# 75%    21.000000
# max    30.000000

# %%
#seeing top 5 rows to get an idea of what df looks like
vc_5_to_14.head()
# Out:
#                   Name        Country  Years active Proven victims  \
# 0  Carl Eugene Watts    United States  1974 to 1982  14
# 1  Philipp Tyurin       Soviet Union   1945 to 1946  14
# 2  Zdzisław Marchwicki  Poland         1964 to 1970  14
# 3  Monster of Florence  Italy          1968 to 1985  14
# 4  Joachim Kroll        West Germany   1955 to 1976  14
#
#   Possible victims  \
# 0  80+
# 1  29
# 2  21+
# 3  16
# 4  NaN
#
# ...

# %%
#seeing bottom 5 rows to get an idea of what df looks like
vc_5_to_14.tail()
# Out:
#               Name  \
# 159  Michel Peiry
# 160  Hubert Pilčík
# 161  Thomas Dillon
# 162  Joe Metheny
# 163  Sek Kim Wah
#
#                                                                                    Country  \
# 159  Switzerland\r\nFrance\r\nUnited States\r\nYugoslavia (suspected)\r\nItaly (suspected)
# 160  Czechoslovakia
# 161  United States
# 162  United States
# 163  Singapore
#
#                      Years active Proven victims Possible victims  \
# 159  1981 to 1987                  5              11
# 160  1948 to 1951                  5              10+
# 161  1989 to 1992                  5              NaN
# 162  1976 to 1996                  5              10
# 163  30 June 1983 to 23 July 1983  5              -
#
# ...

# %%
#finding avg, min, and max
vc_5_to_14.describe()
# Out:
#                      Name        Country Years active Proven victims  \
# count   164                164            164          164
# unique  164                48             150          14
# top     Carl Eugene Watts  United States  1984         11
# freq    1                  61             2            24
#
#        Possible victims  \
# count   98
# unique  51
# top     11
# freq    9
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Notes
# count   164
# unique  164
# ...

# %%
#seeing top 5 rows to get an idea of what df looks like
vc_lessthan_5.head()
# Out:
#                 Name  \
# 0  Charlie Brandt
# 1  Robert Black
# 2  Max Gufler
# 3  Ernesto Picchioni
# 4  Baekuni
#
#                                                                                                               Country  \
# 0  United States
# 1  United Kingdom\r\nIreland (suspected)\r\nWest Germany (suspected)\r\nNetherlands (suspected)\r\nFrance (suspected)
# 2  Austria
# 3  Italy
# 4  Indonesia
#
#        Years active  Proven victims Possible victims  \
# 0  1971 to 2004      4               29
# 1  1981 to 1986      4               18+
# 2  1946 to 1958      4               18
# 3  1949 and earlier  4               16
# 4  1993 to 2010      4               14
#
# ...

# %%
#seeing bottom 5 rows to get an idea of what df looks like
vc_lessthan_5.tail()
# Out:
#                    Name         Country  Years active  Proven victims  \
# 24  Leonarda Cianciulli  Italy           1939 to 1940  3
# 25  Özkan Zengin         Turkey          2008          3
# 26  Albert Fish          United States   1924 to 1932  3
# 27  Heriberto Seda       United States   1990 to 1996  3
# 28  John Martin          United Kingdom  1995          3
#
#    Possible victims  \
# 24  -
# 25  4
# 26  9-100+
# 27  8+
# 28  3+
#
# ...

# %%
#finding avg, min, and max
vc_lessthan_5.describe()
# Out:
#        Proven victims
# count  29.000000
# mean   3.379310
# std    0.493804
# min    3.000000
# 25%    3.000000
# 50%    3.000000
# 75%    4.000000
# max    4.000000

# %%
#concatinating all 4 tables together
frames = [highest_vc, vc_15_to_30, vc_5_to_14, vc_lessthan_5]
result = pd.concat(frames)
result
# Out:
#                                         Name  \
# 0    Luis Garavito
# 1    Pedro López
# 2    Javed Iqbal
# 3    Mikhail Popkov
# 4    Daniel Camargo Barbosa
# 5    Pedro Rodrigues Filho
# 6    Kampatimar Shankariya
# 7    Yang Xinhai
# 8    Samuel Little
# 9    Giuseppe Greco
# 10   Andrei Chikatilo
# 11   Anatoly Onoprienko
# 12   Ivan Maleshoff
# 13   Florisvaldo de Oliveira
# 14   Willy Pickton
# 15   Gary Ridgway
# 16   Alexander Pichushkin
# 17   Wang Qiang
# 18   Ahmad Suradji
# 19   Raman Raghav
# 20   Tiago Henrique Gomes da Rocha
# 21   Moses Sithole
# 22   Serhiy Tkach
# 23   Gennady Mikhasevich
# 24   Hadj Mohammed Mesfewi
# 25   Vera Renczi
# 26   Ted Bundy
# 27   Clementine Barnabet
# 28   John Wayne Gacy
# 29   Ali Asghar Borujerdi
# 30   Vasili Komaroff
# 31   Fernando Hernández Leyva
# 32   Ramadan Abdel Rehim Mansour
# 33   Radik Tagirov
# 0    Karl Denke
# 1    Francisco das Chagas Rodrigues de Brito
# 2    Luis Gregorio Ramírez Maestre
# ...

# %%
result.describe()
# Out:
#                  Name        Country  Years active Proven victims  \
# count   305            305            305           305
# unique  305            74             260           55
# top     Luis Garavito  United States  1992 to 1999  11
# freq    1              92             3             24
#
#        Possible victims  \
# count   237
# unique  108
# top     16
# freq    11
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Notes
# count   305
# unique  305
# ...

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
#code to allow us to see every piece of data in the tables
pd.set_option('display.max_rows', None)     #allows us to see all rows
pd.set_option('display.max_columns', None)  #allows us to see all columns
pd.set_option('display.width', None)        #allows all columns to be in same line
pd.set_option('display.max_colwidth', -1)   #allows columns to not be truncated (max width of column)
# Out:
# C:\Users\timle\AppData\Local\Temp/ipykernel_48448/156121013.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)   #allows columns to not be truncated (max width of column)

# %%
sk = result['Proven victims']
sk
# 4 variables are ranges rather than just single values, 
# they need to be changed for the data to be converted to int and utilized properly in a chart
# Out:
# 0      138
# 1      110
# 2      100
# 3      83
# 4      72
# 5      71
# 6      70
# 7      67
# 8      60
# 9      58
# 10     53
# 11     52
# 12     50
# 13     50
# 14     49
# 15     49
# 16     48
# 17     45
# 18     42
# 19     41
# 20     39
# 21     38
# 22     36
# 23     36
# 24     36
# 25     35
# 26     35
# 27     35
# 28     33
# 29     33
# 30     33
# 31     33
# 32     32
# 33     32
# 0      30
# 1      30
# 2      30
# 3      28
# 4      28
# 5      27
# 6      27
# 7      26
# 8      25
# 9      25
# 10     24
# 11     24
# 12     24
# 13     23
# 14     23
# 15     23
# 16     22
# 17     22
# 18     21
# 19     21
# 20     21
# 21     21
# 22     21
# 23     21
# 24     20
# 25     20
# 26     20
# 27     20
# 28     19
# 29     19
# 30     19
# 31     19
# 32     19
# 33     19
# 34     19
# 35     19
# 36     19
# 37     19
# 38     18
# 39     18
# 40     18
# 41     18
# 42     18
# 43     18
# 44     18
# 45     17
# 46     17
# 47     17
# 48     17
# ...

# %%
###NOT WORKING### still needs work
#changing data range '11-16' single number so I can convert to int
sk = sk.replace('11–16', '11')
sk
# Out:
# 0      138
# 1      110
# 2      100
# 3      83
# 4      72
# 5      71
# 6      70
# 7      67
# 8      60
# 9      58
# 10     53
# 11     52
# 12     50
# 13     50
# 14     49
# 15     49
# 16     48
# 17     45
# 18     42
# 19     41
# 20     39
# 21     38
# 22     36
# 23     36
# 24     36
# 25     35
# 26     35
# 27     35
# 28     33
# 29     33
# 30     33
# 31     33
# 32     32
# 33     32
# 0      30
# 1      30
# 2      30
# 3      28
# 4      28
# 5      27
# 6      27
# 7      26
# 8      25
# 9      25
# 10     24
# 11     24
# 12     24
# 13     23
# 14     23
# 15     23
# 16     22
# 17     22
# 18     21
# 19     21
# 20     21
# 21     21
# 22     21
# 23     21
# 24     20
# 25     20
# 26     20
# 27     20
# 28     19
# 29     19
# 30     19
# 31     19
# 32     19
# 33     19
# 34     19
# 35     19
# 36     19
# 37     19
# 38     18
# 39     18
# 40     18
# 41     18
# 42     18
# 43     18
# 44     18
# 45     17
# 46     17
# 47     17
# 48     17
# ...

# %%
#changing data range '9-13' single number so I can convert to int
sk = sk.replace('9–13', '9')
sk
# Out:
# 0      138
# 1      110
# 2      100
# 3      83
# 4      72
# 5      71
# 6      70
# 7      67
# 8      60
# 9      58
# 10     53
# 11     52
# 12     50
# 13     50
# 14     49
# 15     49
# 16     48
# 17     45
# 18     42
# 19     41
# 20     39
# 21     38
# 22     36
# 23     36
# 24     36
# 25     35
# 26     35
# 27     35
# 28     33
# 29     33
# 30     33
# 31     33
# 32     32
# 33     32
# 0      30
# 1      30
# 2      30
# 3      28
# 4      28
# 5      27
# 6      27
# 7      26
# 8      25
# 9      25
# 10     24
# 11     24
# 12     24
# 13     23
# 14     23
# 15     23
# 16     22
# 17     22
# 18     21
# 19     21
# 20     21
# 21     21
# 22     21
# 23     21
# 24     20
# 25     20
# 26     20
# 27     20
# 28     19
# 29     19
# 30     19
# 31     19
# 32     19
# 33     19
# 34     19
# 35     19
# 36     19
# 37     19
# 38     18
# 39     18
# 40     18
# 41     18
# 42     18
# 43     18
# 44     18
# 45     17
# 46     17
# 47     17
# 48     17
# ...

# %%
#changing data range '8-15' single number so I can convert to int
sk = sk.replace('8–15', '8')
sk
# Out:
# 0      138
# 1      110
# 2      100
# 3      83
# 4      72
# 5      71
# 6      70
# 7      67
# 8      60
# 9      58
# 10     53
# 11     52
# 12     50
# 13     50
# 14     49
# 15     49
# 16     48
# 17     45
# 18     42
# 19     41
# 20     39
# 21     38
# 22     36
# 23     36
# 24     36
# 25     35
# 26     35
# 27     35
# 28     33
# 29     33
# 30     33
# 31     33
# 32     32
# 33     32
# 0      30
# 1      30
# 2      30
# 3      28
# 4      28
# 5      27
# 6      27
# 7      26
# 8      25
# 9      25
# 10     24
# 11     24
# 12     24
# 13     23
# 14     23
# 15     23
# 16     22
# 17     22
# 18     21
# 19     21
# 20     21
# 21     21
# 22     21
# 23     21
# 24     20
# 25     20
# 26     20
# 27     20
# 28     19
# 29     19
# 30     19
# 31     19
# 32     19
# 33     19
# 34     19
# 35     19
# 36     19
# 37     19
# 38     18
# 39     18
# 40     18
# 41     18
# 42     18
# 43     18
# 44     18
# 45     17
# 46     17
# 47     17
# 48     17
# ...

# %%
#changing data range '8-11+' single number so I can convert to int
sk = sk.replace('8–11+', '8')
sk
# Out:
# 0      138
# 1      110
# 2      100
# 3      83
# 4      72
# 5      71
# 6      70
# 7      67
# 8      60
# 9      58
# 10     53
# 11     52
# 12     50
# 13     50
# 14     49
# 15     49
# 16     48
# 17     45
# 18     42
# 19     41
# 20     39
# 21     38
# 22     36
# 23     36
# 24     36
# 25     35
# 26     35
# 27     35
# 28     33
# 29     33
# 30     33
# 31     33
# 32     32
# 33     32
# 0      30
# 1      30
# 2      30
# 3      28
# 4      28
# 5      27
# 6      27
# 7      26
# 8      25
# 9      25
# 10     24
# 11     24
# 12     24
# 13     23
# 14     23
# 15     23
# 16     22
# 17     22
# 18     21
# 19     21
# 20     21
# 21     21
# 22     21
# 23     21
# 24     20
# 25     20
# 26     20
# 27     20
# 28     19
# 29     19
# 30     19
# 31     19
# 32     19
# 33     19
# 34     19
# 35     19
# 36     19
# 37     19
# 38     18
# 39     18
# 40     18
# 41     18
# 42     18
# 43     18
# 44     18
# 45     17
# 46     17
# 47     17
# 48     17
# ...

# %%
print(result['Proven victims'].astype(int))
# Out:
# 0      138
# 1      110
# 2      100
# 3      83
# 4      72
# 5      71
# 6      70
# 7      67
# 8      60
# 9      58
# 10     53
# 11     52
# 12     50
# 13     50
# 14     49
# 15     49
# 16     48
# 17     45
# 18     42
# 19     41
# 20     39
# 21     38
# 22     36
# 23     36
# 24     36
# 25     35
# 26     35
# 27     35
# 28     33
# 29     33
# 30     33
# 31     33
# 32     32
# 33     32
# 0      30
# 1      30
# 2      30
# 3      28
# 4      28
# 5      27
# 6      27
# 7      26
# 8      25
# 9      25
# 10     24
# 11     24
# 12     24
# 13     23
# 14     23
# 15     23
# 16     22
# 17     22
# 18     21
# 19     21
# 20     21
# 21     21
# 22     21
# 23     21
# 24     20
# 25     20
# 26     20
# 27     20
# 28     19
# 29     19
# 30     19
# 31     19
# 32     19
# 33     19
# 34     19
# 35     19
# 36     19
# 37     19
# 38     18
# 39     18
# 40     18
# 41     18
# 42     18
# 43     18
# 44     18
# 45     17
# 46     17
# 47     17
# 48     17
# ...

# %%
###NEED TO FIX DATA BEFORE VISUALIZING###
#importing stuff for visuals
import matplotlib.pyplot as plt
from matplotlib import style


#line chart
fig1 = sk.plot(x= 'Proven Victims', y= 'Name', kind='line', color = 'red')
plt.title('Total Proven Victims Per Serial Killer',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.xlabel('Total Proven Victims',color = 'black')
plt.ylabel('Serial Killer',color = 'black')
plt.savefig('linechart_single.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48448/3460324833.py in <module>
#       6
#       7 #line chart
# ----> 8 fig1 = sk.plot(x= 'Proven Victims', y= 'Name', kind='line', color = 'red')
#       9 plt.title('Total Proven Victims Per Serial Killer',color = 'black')
#      10 plt.xticks(color = 'black')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
# ...

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# I was surprised that there are ranges for Proven victims for some serial killers.
#
#
# 2. Do you have any concerns about your dataset?
# How I will be able to properly clean everything so that it's easy to read/understand.
#
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# Need to fix Proven Victims column in order to get a proper visualization.

# %% [markdown]
# A1: I was surprised that there are ranges for Proven victims for some serial killers.
#
# A2: How I will be able to properly clean everything so that it's easy to read/understand.
#
# A3: Need to fix Proven Victims column in order to get a proper visualization.
